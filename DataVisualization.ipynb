# %%
import os

import pandas as pd

from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn import metrics
import matplotlib.pyplot as plt

from itertools import cycle

# %%
datasetPath = os.path.join(os.getcwd(),'wine-clustering.csv')
dataset = pd.read_csv(datasetPath)

# %%
m = TSNE(learning_rate=50)

twoDimensionateData = m.fit_transform(dataset)

x = twoDimensionateData[:,0]
y = twoDimensionateData[:,1]

# %%
plt.scatter(x,y)
plt.show()

# %%
pca = PCA(n_components=2)

pca_data = pca.fit_transform(dataset)

pcaX = x = pca_data[:,0]
pcaY = twoDimensionateData[:,1]

# %%
plt.scatter(pcaX,pcaY)
plt.show()
