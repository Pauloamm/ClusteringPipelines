# %%
import os

import pandas as pd

from sklearn.cluster import DBSCAN
from sklearn import metrics
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt

from itertools import cycle

# %%
blobs,blob_labels = make_blobs(n_samples=300, centers=4, cluster_std=0.60, random_state=0)


datasetPath = os.path.join(os.getcwd(),'wine-clustering.csv')
dataset = pd.read_csv(datasetPath)

# %%
#TEST
dataset = blobs
plt.scatter(blobs[:, 0], blobs[:, 1])
plt.show()

# %%
dbscan = DBSCAN(eps=0.6, min_samples=5).fit(dataset)

labels = dbscan.labels_

# %%
plt.scatter(blobs[:, 0], blobs[:, 1],c=dbscan.labels_)
plt.show()
